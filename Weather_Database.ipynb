# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
   
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coihaique
# Processing Record 2 of Set 1 | lagoa
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | vieste
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | russkaya polyana
# Processing Record 11 of Set 1 | kahului
# Processing Record 12 of Set 1 | guatire
# Processing Record 13 of Set 1 | san patricio
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | tongzi
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | kudahuvadhoo
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | losevo
# Processing Record 21 of Set 1 | thinadhoo
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | tezu
# Processing Record 26 of Set 1 | san lazaro
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | inuvik
# Processing Record 34 of Set 1 | vicuna
# Processing Record 35 of Set 1 | surt
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | asau
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | rorvik
# Processing Record 41 of Set 1 | turukhansk
# Processing Record 42 of Set 1 | cayenne
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | ambilobe
# Processing Record 45 of Set 1 | mangrol
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | olafsvik
# Processing Record 48 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 1 | puerto del rosario
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | great falls
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | pevek
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | kruisfontein
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | lang suan
# Processing Record 13 of Set 2 | saint-joseph
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | mount isa
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | beringovskiy
# Processing Record 21 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 2 | la macarena
# Processing Record 23 of Set 2 | carballo
# Processing Record 24 of Set 2 | cap malheureux
# Processing Record 25 of Set 2 | panguna
# Processing Record 26 of Set 2 | kuytun
# Processing Record 27 of Set 2 | agadez
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | puma
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | khonsa
# Processing Record 33 of Set 2 | sisimiut
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | kidal
# Processing Record 36 of Set 2 | pimentel
# Processing Record 37 of Set 2 | taggia
# Processing Record 38 of Set 2 | shache
# Processing Record 39 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 2 | sri aman
# Processing Record 42 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | kavieng
# Processing Record 45 of Set 2 | mount darwin
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | mount pleasant
# Processing Record 48 of Set 2 | qaanaaq
# Processing Record 49 of Set 2 | esperance
# Processing Record 50 of Set 2 | kostino
# Processing Record 1 of Set 3 | vilhena
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | pisco
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | faya
# Processing Record 11 of Set 3 | nuuk
# Processing Record 12 of Set 3 | marovoay
# Processing Record 13 of Set 3 | provideniya
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | nurota
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | kabo
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | kisangani
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | palencia
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | polson
# Processing Record 25 of Set 3 | emba
# Processing Record 26 of Set 3 | yaan
# Processing Record 27 of Set 3 | georgetown
# Processing Record 28 of Set 3 | potenza
# Processing Record 29 of Set 3 | alice springs
# Processing Record 30 of Set 3 | yumen
# Processing Record 31 of Set 3 | chinhoyi
# Processing Record 32 of Set 3 | vanimo
# Processing Record 33 of Set 3 | hambantota
# Processing Record 34 of Set 3 | seydi
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | panalingaan
# Processing Record 37 of Set 3 | karratha
# Processing Record 38 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | raglan
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | buchanan
# Processing Record 43 of Set 3 | berdigestyakh
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | puerto escondido
# Processing Record 47 of Set 3 | chilca
# Processing Record 48 of Set 3 | hamilton
# Processing Record 49 of Set 3 | port lincoln
# Processing Record 50 of Set 3 | fuerte olimpo
# Processing Record 1 of Set 4 | we
# City not found. Skipping...
# Processing Record 2 of Set 4 | san quintin
# Processing Record 3 of Set 4 | lincolnton
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | havoysund
# Processing Record 7 of Set 4 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | rolla
# Processing Record 10 of Set 4 | bayaguana
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | aden
# Processing Record 14 of Set 4 | vaini
# Processing Record 15 of Set 4 | luis correia
# Processing Record 16 of Set 4 | talcahuano
# Processing Record 17 of Set 4 | honavar
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | culpeper
# Processing Record 20 of Set 4 | klaksvik
# Processing Record 21 of Set 4 | livingston
# Processing Record 22 of Set 4 | senneterre
# Processing Record 23 of Set 4 | coahuayana
# Processing Record 24 of Set 4 | general roca
# Processing Record 25 of Set 4 | constitucion
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | egvekinot
# Processing Record 28 of Set 4 | kangaatsiaq
# Processing Record 29 of Set 4 | pangai
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | sorland
# Processing Record 33 of Set 4 | copala
# Processing Record 34 of Set 4 | san-pedro
# Processing Record 35 of Set 4 | boa vista
# Processing Record 36 of Set 4 | monchegorsk
# Processing Record 37 of Set 4 | vestmannaeyjar
# Processing Record 38 of Set 4 | naze
# Processing Record 39 of Set 4 | dzerzhinskoye
# Processing Record 40 of Set 4 | honiara
# Processing Record 41 of Set 4 | chegem
# Processing Record 42 of Set 4 | omboue
# Processing Record 43 of Set 4 | shushtar
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | portland
# Processing Record 46 of Set 4 | namibe
# Processing Record 47 of Set 4 | christchurch
# Processing Record 48 of Set 4 | tutoia
# Processing Record 49 of Set 4 | faanui
# Processing Record 50 of Set 4 | bo phloi
# Processing Record 1 of Set 5 | nortelandia
# Processing Record 2 of Set 5 | sitka
# Processing Record 3 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 5 | moose factory
# Processing Record 7 of Set 5 | port macquarie
# Processing Record 8 of Set 5 | buala
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | xining
# Processing Record 11 of Set 5 | permet
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | haines junction
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | canutama
# Processing Record 16 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 5 | mwinilunga
# Processing Record 18 of Set 5 | huanren
# Processing Record 19 of Set 5 | podporozhye
# Processing Record 20 of Set 5 | nisia floresta
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | zhuhai
# Processing Record 23 of Set 5 | mendoza
# Processing Record 24 of Set 5 | tripoli
# Processing Record 25 of Set 5 | itaituba
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | bulgan
# Processing Record 28 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 5 | pozoblanco
# Processing Record 30 of Set 5 | nouadhibou
# Processing Record 31 of Set 5 | buraydah
# Processing Record 32 of Set 5 | ngunguru
# Processing Record 33 of Set 5 | lerwick
# Processing Record 34 of Set 5 | tulsa
# Processing Record 35 of Set 5 | sechura
# Processing Record 36 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 5 | elizabeth city
# Processing Record 39 of Set 5 | savannah bight
# Processing Record 40 of Set 5 | santo domingo
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | ler
# Processing Record 43 of Set 5 | dunedin
# Processing Record 44 of Set 5 | gigmoto
# Processing Record 45 of Set 5 | biak
# Processing Record 46 of Set 5 | bubaque
# Processing Record 47 of Set 5 | makat
# Processing Record 48 of Set 5 | tuy hoa
# Processing Record 49 of Set 5 | waingapu
# Processing Record 50 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 6 | airai
# Processing Record 2 of Set 6 | hofn
# Processing Record 3 of Set 6 | san miguelito
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | yuanping
# Processing Record 6 of Set 6 | abha
# Processing Record 7 of Set 6 | chaozhou
# Processing Record 8 of Set 6 | souillac
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | kontagora
# Processing Record 11 of Set 6 | taoudenni
# Processing Record 12 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | chimbarongo
# Processing Record 15 of Set 6 | cervo
# Processing Record 16 of Set 6 | aberdeen
# Processing Record 17 of Set 6 | komsomolskiy
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | mao
# Processing Record 20 of Set 6 | bambui
# Processing Record 21 of Set 6 | demba
# Processing Record 22 of Set 6 | murray bridge
# Processing Record 23 of Set 6 | port-gentil
# Processing Record 24 of Set 6 | yarada
# Processing Record 25 of Set 6 | comodoro rivadavia
# Processing Record 26 of Set 6 | provost
# Processing Record 27 of Set 6 | cedar falls
# Processing Record 28 of Set 6 | fuyu
# Processing Record 29 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | dolores
# Processing Record 31 of Set 6 | shimoda
# Processing Record 32 of Set 6 | shingu
# Processing Record 33 of Set 6 | kieta
# Processing Record 34 of Set 6 | cizre
# Processing Record 35 of Set 6 | creel
# Processing Record 36 of Set 6 | saint-philippe
# Processing Record 37 of Set 6 | putina
# Processing Record 38 of Set 6 | muros
# Processing Record 39 of Set 6 | roald
# Processing Record 40 of Set 6 | gizo
# Processing Record 41 of Set 6 | kamenka
# Processing Record 42 of Set 6 | peniche
# Processing Record 43 of Set 6 | mercedes
# Processing Record 44 of Set 6 | nanortalik
# Processing Record 45 of Set 6 | kurumkan
# Processing Record 46 of Set 6 | tigil
# Processing Record 47 of Set 6 | ballina
# Processing Record 48 of Set 6 | dolna banja
# City not found. Skipping...
# Processing Record 49 of Set 6 | havre-saint-pierre
# Processing Record 50 of Set 6 | bethel
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | minna
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | los llanos de aridane
# Processing Record 5 of Set 7 | guerrero negro
# Processing Record 6 of Set 7 | sao joao da barra
# Processing Record 7 of Set 7 | mujiayingzi
# Processing Record 8 of Set 7 | san cristobal
# Processing Record 9 of Set 7 | erzin
# Processing Record 10 of Set 7 | aban
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | half moon bay
# Processing Record 13 of Set 7 | gore
# Processing Record 14 of Set 7 | khoy
# Processing Record 15 of Set 7 | sorong
# Processing Record 16 of Set 7 | caravelas
# Processing Record 17 of Set 7 | peleduy
# Processing Record 18 of Set 7 | moiyabana
# City not found. Skipping...
# Processing Record 19 of Set 7 | shelton
# Processing Record 20 of Set 7 | dores do indaia
# Processing Record 21 of Set 7 | kimbe
# Processing Record 22 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | krasnoselkup
# Processing Record 26 of Set 7 | beyneu
# Processing Record 27 of Set 7 | inhambane
# Processing Record 28 of Set 7 | olinda
# Processing Record 29 of Set 7 | khatanga
# Processing Record 30 of Set 7 | bilibino
# Processing Record 31 of Set 7 | redmond
# Processing Record 32 of Set 7 | waipawa
# Processing Record 33 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 7 | miles city
# Processing Record 35 of Set 7 | cascais
# Processing Record 36 of Set 7 | zmeinogorsk
# Processing Record 37 of Set 7 | shaping
# Processing Record 38 of Set 7 | paita
# Processing Record 39 of Set 7 | hirado
# Processing Record 40 of Set 7 | manta
# Processing Record 41 of Set 7 | henzada
# City not found. Skipping...
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | santo augusto
# Processing Record 45 of Set 7 | san andres
# Processing Record 46 of Set 7 | husavik
# Processing Record 47 of Set 7 | lakes entrance
# Processing Record 48 of Set 7 | corpus christi
# Processing Record 49 of Set 7 | kikwit
# Processing Record 50 of Set 7 | gijon
# Processing Record 1 of Set 8 | cabo san lucas
# Processing Record 2 of Set 8 | varkkallai
# Processing Record 3 of Set 8 | borovskoy
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | shaki
# Processing Record 6 of Set 8 | westport
# Processing Record 7 of Set 8 | sao filipe
# Processing Record 8 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 8 | aldan
# Processing Record 10 of Set 8 | koutiala
# Processing Record 11 of Set 8 | calbuco
# Processing Record 12 of Set 8 | zalantun
# Processing Record 13 of Set 8 | yenagoa
# Processing Record 14 of Set 8 | waitati
# Processing Record 15 of Set 8 | coquimbo
# Processing Record 16 of Set 8 | balotra
# Processing Record 17 of Set 8 | banda aceh
# Processing Record 18 of Set 8 | ouesso
# Processing Record 19 of Set 8 | ramhormoz
# Processing Record 20 of Set 8 | crestview
# Processing Record 21 of Set 8 | kawalu
# Processing Record 22 of Set 8 | quelimane
# Processing Record 23 of Set 8 | remedios
# Processing Record 24 of Set 8 | galanesti
# Processing Record 25 of Set 8 | ishigaki
# Processing Record 26 of Set 8 | wukari
# Processing Record 27 of Set 8 | nantucket
# Processing Record 28 of Set 8 | salalah
# Processing Record 29 of Set 8 | phan thiet
# Processing Record 30 of Set 8 | port hedland
# Processing Record 31 of Set 8 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 32 of Set 8 | oranjemund
# Processing Record 33 of Set 8 | cabadiangan
# Processing Record 34 of Set 8 | atar
# Processing Record 35 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 36 of Set 8 | clarence town
# Processing Record 37 of Set 8 | itarema
# Processing Record 38 of Set 8 | roebourne
# Processing Record 39 of Set 8 | antofagasta
# Processing Record 40 of Set 8 | pau brasil
# Processing Record 41 of Set 8 | ulaangom
# Processing Record 42 of Set 8 | salinas
# Processing Record 43 of Set 8 | sulangan
# Processing Record 44 of Set 8 | touba
# Processing Record 45 of Set 8 | zverinogolovskoye
# Processing Record 46 of Set 8 | malpe
# Processing Record 47 of Set 8 | ohangaron
# Processing Record 48 of Set 8 | todos santos
# Processing Record 49 of Set 8 | ordubad
# Processing Record 50 of Set 8 | vaitape
# Processing Record 1 of Set 9 | birin
# Processing Record 2 of Set 9 | khammam
# Processing Record 3 of Set 9 | minot
# Processing Record 4 of Set 9 | luderitz
# Processing Record 5 of Set 9 | fort nelson
# Processing Record 6 of Set 9 | vila franca do campo
# Processing Record 7 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 9 | moorhead
# Processing Record 9 of Set 9 | qasigiannguit
# Processing Record 10 of Set 9 | pangnirtung
# Processing Record 11 of Set 9 | zlitan
# Processing Record 12 of Set 9 | valdivia
# Processing Record 13 of Set 9 | imeni poliny osipenko
# Processing Record 14 of Set 9 | takapau
# Processing Record 15 of Set 9 | nelson bay
# Processing Record 16 of Set 9 | okhotsk
# Processing Record 17 of Set 9 | la ronge
# Processing Record 18 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 9 | japura
# Processing Record 20 of Set 9 | mackay
# Processing Record 21 of Set 9 | gobabis
# Processing Record 22 of Set 9 | the valley
# Processing Record 23 of Set 9 | warkworth
# Processing Record 24 of Set 9 | aksarka
# Processing Record 25 of Set 9 | forbes
# Processing Record 26 of Set 9 | mobaye
# Processing Record 27 of Set 9 | saint-georges
# Processing Record 28 of Set 9 | flinders
# Processing Record 29 of Set 9 | providencia
# Processing Record 30 of Set 9 | bull savanna
# Processing Record 31 of Set 9 | littleton
# Processing Record 32 of Set 9 | victoria
# Processing Record 33 of Set 9 | baijiantan
# Processing Record 34 of Set 9 | kamphaeng phet
# Processing Record 35 of Set 9 | toro
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | baruun-urt
# Processing Record 38 of Set 9 | praya
# Processing Record 39 of Set 9 | taltal
# Processing Record 40 of Set 9 | dori
# Processing Record 41 of Set 9 | alugan
# Processing Record 42 of Set 9 | kushiro
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | catamarca
# Processing Record 45 of Set 9 | berbera
# Processing Record 46 of Set 9 | buarcos
# Processing Record 47 of Set 9 | kaihua
# Processing Record 48 of Set 9 | uige
# Processing Record 49 of Set 9 | rumonge
# Processing Record 50 of Set 9 | kentville
# Processing Record 1 of Set 10 | milkovo
# Processing Record 2 of Set 10 | gambela
# Processing Record 3 of Set 10 | auki
# Processing Record 4 of Set 10 | ewa beach
# Processing Record 5 of Set 10 | campbeltown
# Processing Record 6 of Set 10 | arman
# Processing Record 7 of Set 10 | port hardy
# Processing Record 8 of Set 10 | tirumullaivasal
# Processing Record 9 of Set 10 | richards bay
# Processing Record 10 of Set 10 | mareeba
# Processing Record 11 of Set 10 | fortuna foothills
# Processing Record 12 of Set 10 | rochegda
# Processing Record 13 of Set 10 | ambon
# Processing Record 14 of Set 10 | wellington
# Processing Record 15 of Set 10 | adrar
# Processing Record 16 of Set 10 | ketchikan
# Processing Record 17 of Set 10 | bemidji
# Processing Record 18 of Set 10 | burns lake
# Processing Record 19 of Set 10 | khanpur
# Processing Record 20 of Set 10 | chaoyang
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | zhanaozen
# Processing Record 23 of Set 10 | riyadh
# Processing Record 24 of Set 10 | vardo
# Processing Record 25 of Set 10 | aqtobe
# Processing Record 26 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 10 | matay
# Processing Record 28 of Set 10 | sutton
# Processing Record 29 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 10 | bacarra
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | meulaboh
# Processing Record 33 of Set 10 | madang
# Processing Record 34 of Set 10 | channel-port aux basques
# Processing Record 35 of Set 10 | novaya bryan
# Processing Record 36 of Set 10 | prince rupert
# Processing Record 37 of Set 10 | trelew
# Processing Record 38 of Set 10 | tiarei
# Processing Record 39 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 10 | karasjok
# Processing Record 41 of Set 10 | igrim
# Processing Record 42 of Set 10 | katherine
# Processing Record 43 of Set 10 | markova
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | hasaki
# Processing Record 46 of Set 10 | botwood
# Processing Record 47 of Set 10 | cape elizabeth
# City not found. Skipping...
# Processing Record 48 of Set 10 | rocha
# Processing Record 49 of Set 10 | hobyo
# Processing Record 50 of Set 10 | phulji
# Processing Record 1 of Set 11 | bindura
# Processing Record 2 of Set 11 | lata
# Processing Record 3 of Set 11 | linhai
# Processing Record 4 of Set 11 | gharb
# City not found. Skipping...
# Processing Record 5 of Set 11 | benalla
# Processing Record 6 of Set 11 | warmbad
# Processing Record 7 of Set 11 | koungou
# Processing Record 8 of Set 11 | labuhan
# Processing Record 9 of Set 11 | mayumba
# Processing Record 10 of Set 11 | verkhoyansk
# Processing Record 11 of Set 11 | xuanhua
# Processing Record 12 of Set 11 | cairns
# Processing Record 13 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 11 | prieska
# Processing Record 15 of Set 11 | rio gallegos
# Processing Record 16 of Set 11 | lavrentiya
# Processing Record 17 of Set 11 | cotacachi
# Processing Record 18 of Set 11 | baherden
# Processing Record 19 of Set 11 | broome
# Processing Record 20 of Set 11 | khuzdar
# Processing Record 21 of Set 11 | sazonovo
# Processing Record 22 of Set 11 | cabedelo
# Processing Record 23 of Set 11 | puri
# Processing Record 24 of Set 11 | ruteng
# Processing Record 25 of Set 11 | bramsche
# Processing Record 26 of Set 11 | muzhi
# Processing Record 27 of Set 11 | kuala kedah
# Processing Record 28 of Set 11 | tak bai
# Processing Record 29 of Set 11 | naron
# Processing Record 30 of Set 11 | anloga
# Processing Record 31 of Set 11 | mezen
# Processing Record 32 of Set 11 | grenfell
# Processing Record 33 of Set 11 | champerico
# Processing Record 34 of Set 11 | kita
# Processing Record 35 of Set 11 | sohag
# Processing Record 36 of Set 11 | minsk mazowiecki
# Processing Record 37 of Set 11 | belokurikha
# Processing Record 38 of Set 11 | pauini
# Processing Record 39 of Set 11 | barabai
# Processing Record 40 of Set 11 | yilan
# Processing Record 41 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 11 | alexandria
# Processing Record 43 of Set 11 | ferrol
# Processing Record 44 of Set 11 | opelousas
# Processing Record 45 of Set 11 | tura
# Processing Record 46 of Set 11 | hovd
# Processing Record 47 of Set 11 | antalaha
# Processing Record 48 of Set 11 | ca mau
# Processing Record 49 of Set 11 | bom jesus do galho
# Processing Record 50 of Set 11 | axim
# Processing Record 1 of Set 12 | monrovia
# Processing Record 2 of Set 12 | jijiga
# Processing Record 3 of Set 12 | college
# Processing Record 4 of Set 12 | voh
# Processing Record 5 of Set 12 | stornoway
# Processing Record 6 of Set 12 | bafoulabe
# Processing Record 7 of Set 12 | byron bay
# Processing Record 8 of Set 12 | san mateo del mar
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | asfi
# Processing Record 11 of Set 12 | umm lajj
# Processing Record 12 of Set 12 | soe
# Processing Record 13 of Set 12 | san jeronimo
# Processing Record 14 of Set 12 | loandjili
# Processing Record 15 of Set 12 | zapolyarnyy
# Processing Record 16 of Set 12 | vostok
# Processing Record 17 of Set 12 | north bend
# Processing Record 18 of Set 12 | halifax
# Processing Record 19 of Set 12 | santa maria
# Processing Record 20 of Set 12 | usakos
# Processing Record 21 of Set 12 | la orilla
# Processing Record 22 of Set 12 | banjar
# Processing Record 23 of Set 12 | hervey bay
# Processing Record 24 of Set 12 | teberda
# Processing Record 25 of Set 12 | lahat
# Processing Record 26 of Set 12 | whitehorse
# Processing Record 27 of Set 12 | kemijarvi
# Processing Record 28 of Set 12 | conchas
# Processing Record 29 of Set 12 | raymond
# Processing Record 30 of Set 12 | ostrovnoy
# Processing Record 31 of Set 12 | rottingdean
# Processing Record 32 of Set 12 | goshen
# Processing Record 33 of Set 12 | puerto ayacucho
# Processing Record 34 of Set 12 | chadiza
# Processing Record 35 of Set 12 | kathu
# Processing Record 36 of Set 12 | hualmay
# Processing Record 37 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 12 | vitim
# Processing Record 39 of Set 12 | rio tercero
# Processing Record 40 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 41 of Set 12 | brae
# Processing Record 42 of Set 12 | celestun
# Processing Record 43 of Set 12 | yablonovo
# Processing Record 44 of Set 12 | zeya
# Processing Record 45 of Set 12 | vajszlo
# Processing Record 46 of Set 12 | rundu
# Processing Record 47 of Set 12 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 12 | kedrovyy
# Processing Record 49 of Set 12 | mahebourg
# Processing Record 50 of Set 12 | aviles
# Processing Record 1 of Set 13 | srandakan
# Processing Record 2 of Set 13 | tsuruoka
# Processing Record 3 of Set 13 | marrakesh
# Processing Record 4 of Set 13 | terra santa
# Processing Record 5 of Set 13 | te anau
# Processing Record 6 of Set 13 | san vicente
# Processing Record 7 of Set 13 | inverness
# Processing Record 8 of Set 13 | berlevag
# Processing Record 9 of Set 13 | megion
# Processing Record 10 of Set 13 | rio branco do sul
# Processing Record 11 of Set 13 | kloulklubed
# Processing Record 12 of Set 13 | vagur
# Processing Record 13 of Set 13 | honningsvag
# Processing Record 14 of Set 13 | belmonte
# Processing Record 15 of Set 13 | poum
# Processing Record 16 of Set 13 | encantado
# Processing Record 17 of Set 13 | ekibastuz
# Processing Record 18 of Set 13 | acarau
# Processing Record 19 of Set 13 | dire dawa
# Processing Record 20 of Set 13 | crixas
# Processing Record 21 of Set 13 | sanawad
# Processing Record 22 of Set 13 | pandan
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | zhezkazgan
# Processing Record 25 of Set 13 | dezful
# Processing Record 26 of Set 13 | druzhba
# Processing Record 27 of Set 13 | harper
# Processing Record 28 of Set 13 | aykhal
# Processing Record 29 of Set 13 | kibala
# Processing Record 30 of Set 13 | kerchevskiy
# Processing Record 31 of Set 13 | porto novo
# Processing Record 32 of Set 13 | high prairie
# Processing Record 33 of Set 13 | paka
# Processing Record 34 of Set 13 | sulina
# Processing Record 35 of Set 13 | linxia
# Processing Record 36 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 13 | ukiah
# Processing Record 38 of Set 13 | domodossola
# Processing Record 39 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 13 | yomitan
# City not found. Skipping...
# Processing Record 41 of Set 13 | mapiri
# Processing Record 42 of Set 13 | yerbogachen
# Processing Record 43 of Set 13 | bealanana
# Processing Record 44 of Set 13 | nanakuli
# Processing Record 45 of Set 13 | bradford
# Processing Record 46 of Set 13 | empalme
# Processing Record 47 of Set 13 | pijijiapan
# Processing Record 48 of Set 13 | tete
# Processing Record 49 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 13 | mpika
# Processing Record 1 of Set 14 | kamen-rybolov
# Processing Record 2 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 14 | margate
# Processing Record 4 of Set 14 | elko
# Processing Record 5 of Set 14 | narsaq
# Processing Record 6 of Set 14 | usinsk
# Processing Record 7 of Set 14 | longyan
# Processing Record 8 of Set 14 | sompeta
# Processing Record 9 of Set 14 | puerto quijarro
# Processing Record 10 of Set 14 | angoche
# Processing Record 11 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 12 of Set 14 | zhanakorgan
# Processing Record 13 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 14 | aleksandrovskiy zavod
# Processing Record 15 of Set 14 | solnechnyy
# Processing Record 16 of Set 14 | ust-nera
# Processing Record 17 of Set 14 | najran
# Processing Record 18 of Set 14 | ararat
# Processing Record 19 of Set 14 | omsukchan
# Processing Record 20 of Set 14 | khudumelapye
# Processing Record 21 of Set 14 | dzaoudzi
# Processing Record 22 of Set 14 | wuda
# Processing Record 23 of Set 14 | conde
# Processing Record 24 of Set 14 | mae hong son
# Processing Record 25 of Set 14 | pervomayskiy
# Processing Record 26 of Set 14 | miri
# Processing Record 27 of Set 14 | gunnedah
# Processing Record 28 of Set 14 | olavarria
# Processing Record 29 of Set 14 | kozhevnikovo
# Processing Record 30 of Set 14 | marsaxlokk
# Processing Record 31 of Set 14 | tocopilla
# Processing Record 32 of Set 14 | dhidhdhoo
# Processing Record 33 of Set 14 | igarka
# Processing Record 34 of Set 14 | mayo
# Processing Record 35 of Set 14 | ostersund
# Processing Record 36 of Set 14 | dayong
# Processing Record 37 of Set 14 | bingol
# Processing Record 38 of Set 14 | bosaso
# Processing Record 39 of Set 14 | novikovo
# Processing Record 40 of Set 14 | viransehir
# Processing Record 41 of Set 14 | jalu
# Processing Record 42 of Set 14 | jasper
# Processing Record 43 of Set 14 | mushie
# Processing Record 44 of Set 14 | urumqi
# Processing Record 45 of Set 14 | vila
# Processing Record 46 of Set 14 | saint-gaudens
# Processing Record 47 of Set 14 | singkang
# Processing Record 48 of Set 14 | fairlie
# Processing Record 49 of Set 14 | padang
# Processing Record 50 of Set 14 | yenangyaung
# Processing Record 1 of Set 15 | dalinghe
# City not found. Skipping...
# Processing Record 2 of Set 15 | arrecife
# Processing Record 3 of Set 15 | challans
# Processing Record 4 of Set 15 | millau
# Processing Record 5 of Set 15 | marang
# Processing Record 6 of Set 15 | boende
# Processing Record 7 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 15 | sao lourenco do oeste
# Processing Record 9 of Set 15 | costa rica
# Processing Record 10 of Set 15 | lakselv
# Processing Record 11 of Set 15 | oum hadjer
# Processing Record 12 of Set 15 | palmer
# Processing Record 13 of Set 15 | toamasina
# Processing Record 14 of Set 15 | akyab
# Processing Record 15 of Set 15 | atbasar
# Processing Record 16 of Set 15 | moramanga
# Processing Record 17 of Set 15 | grobina
# Processing Record 18 of Set 15 | ancud
# Processing Record 19 of Set 15 | soyo
# Processing Record 20 of Set 15 | papara
# Processing Record 21 of Set 15 | borama
# City not found. Skipping...
# Processing Record 22 of Set 15 | oudtshoorn
# Processing Record 23 of Set 15 | namatanai
# Processing Record 24 of Set 15 | hay river
# Processing Record 25 of Set 15 | kilemary
# Processing Record 26 of Set 15 | nemuro
# Processing Record 27 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 28 of Set 15 | seymchan
# Processing Record 29 of Set 15 | sakakah
# Processing Record 30 of Set 15 | vila velha
# Processing Record 31 of Set 15 | rafai
# Processing Record 32 of Set 15 | sibolga
# Processing Record 33 of Set 15 | camacha
# Processing Record 34 of Set 15 | carauari
# Processing Record 35 of Set 15 | paso de ovejas
# Processing Record 36 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 15 | manado
# Processing Record 38 of Set 15 | castelnau-le-lez
# Processing Record 39 of Set 15 | alihe
# Processing Record 40 of Set 15 | nagato
# Processing Record 41 of Set 15 | langarud
# Processing Record 42 of Set 15 | xianyang
# Processing Record 43 of Set 15 | evensk
# Processing Record 44 of Set 15 | maharajganj
# Processing Record 45 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 15 | poso
# Processing Record 47 of Set 15 | ossora
# Processing Record 48 of Set 15 | venice
# Processing Record 49 of Set 15 | russell
# Processing Record 50 of Set 15 | makakilo city
# Processing Record 1 of Set 16 | kargasok
# Processing Record 2 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 16 | zaysan
# Processing Record 4 of Set 16 | tchamba
# Processing Record 5 of Set 16 | oneonta
# Processing Record 6 of Set 16 | riom
# Processing Record 7 of Set 16 | seddon
# Processing Record 8 of Set 16 | luba
# Processing Record 9 of Set 16 | tarbes
# Processing Record 10 of Set 16 | galiwinku
# City not found. Skipping...
# Processing Record 11 of Set 16 | tabas
# Processing Record 12 of Set 16 | tamandare
# Processing Record 13 of Set 16 | manakara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
count = len(city_data)
print(count)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Coihaique -45.5752  -72.0662     59.61        47          40
# 1             Lagoa  39.0500  -27.9833     58.14        70          38
# 2    Port Elizabeth -33.9180   25.5701     74.10        89          93
# 3    Ribeira Grande  38.5167  -28.7000     59.40        63          40
# 4            Vieste  41.8825   16.1750     51.04        51           1
# 5       Clyde River  70.4692  -68.5914    -19.97        76          40
# 6             Kapaa  22.0752 -159.3190     80.58        65           0
# 7         Busselton -33.6500  115.3333     63.09        65          87
# 8     Mount Gambier -37.8333  140.7667     62.51        94         100
# 9  Russkaya Polyana  49.4170   31.9201     32.31        85          26
#
#    Wind Speed Country   Current Weather
# 0        9.22      CL  scattered clouds
# 1       25.77      PT  scattered clouds
# 2       13.67      ZA   overcast clouds
# 3       20.71      PT  scattered clouds
# 4        6.71      IT         clear sky
# 5        5.75      CA  scattered clouds
# 6        1.99      US         clear sky
# 7       17.78      AU   overcast clouds
# 8        8.05      AU   overcast clouds
# 9       15.30      UA  scattered clouds

# %%
reorg_city_data = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
reorg_city_data_df = city_data_df[reorg_city_data]
reorg_city_data_df
# Out:
#                City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0         Coihaique      CL -45.5752 -72.0662     59.61        47          40
# 1             Lagoa      PT  39.0500 -27.9833     58.14        70          38
# 2    Port Elizabeth      ZA -33.9180  25.5701     74.10        89          93
# 3    Ribeira Grande      PT  38.5167 -28.7000     59.40        63          40
# 4            Vieste      IT  41.8825  16.1750     51.04        51           1
# ..              ...     ...      ...      ...       ...       ...         ...
# 696            Luba      GQ   3.4568   8.5547     81.03        78         100
# 697          Tarbes      FR  43.2500   0.1667     37.26        93         100
# 698           Tabas      IR  33.5959  56.9244     45.45        28           0
# 699       Tamandare      BR  -8.7597 -35.1047     80.08        79          99
# 700        Manakara      MG -22.1333  48.0167     72.64        81           9
#
#      Wind Speed   Current Weather
# 0          9.22  scattered clouds
# 1         25.77  scattered clouds
# 2         13.67   overcast clouds
# 3         20.71  scattered clouds
# 4          6.71         clear sky
# ..          ...               ...
# 696        7.99   overcast clouds
# 697        2.30               fog
# 698        3.15         clear sky
# 699        9.17   overcast clouds
# 700        1.07         clear sky
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
